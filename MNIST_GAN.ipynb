# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
import matplotlib.pyplot as plt
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
# %matplotlib inline
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
image_side_dimension = 28
h_dim_gen = 256
h_dim_disc = 256
learning_rate = 0.001

graph = tf.Graph()

with graph.as_default():
    
    xavier_init = tf.contrib.layers.xavier_initializer()
    
    # Discriminator net

    X = tf.placeholder(tf.float32, shape=[None, image_side_dimension * image_side_dimension], name='X')
    D_W1 = tf.Variable(xavier_init([image_side_dimension*image_side_dimension, h_dim_disc]), name='D_W1')
    D_b1 = tf.Variable(tf.zeros(shape=[h_dim_disc]), name='D_b1')
    D_W2 = tf.Variable(xavier_init([h_dim_disc, 1]), name='D_W2')
    D_b2 = tf.Variable(tf.zeros(shape=[1]), name='D_b2')
    
    D_theta = [D_W1, D_b1, D_W2, D_b2]

    # Generator net

    Z = tf.placeholder(tf.float32, shape=[None, 100], name='Z')
    G_W1 = tf.Variable(xavier_init([100, h_dim_gen]), name='G_W1')
    G_b1 = tf.Variable(tf.zeros(shape=[h_dim_gen]), name='G_b1')
    G_W2 = tf.Variable(xavier_init([h_dim_gen, image_side_dimension * image_side_dimension]), name='G_W2')
    G_b2 = tf.Variable(tf.zeros(shape=[image_side_dimension * image_side_dimension]), name='G_b2')
    
    G_theta = [G_W1, G_b1, G_W2, G_b2]
    
    def discriminator(x):
        D_h1 = tf.nn.relu(tf.matmul(x, D_W1) + D_b1)
        D_logit = tf.matmul(D_h1, D_W2) + D_b2
        D_prob = tf.sigmoid(D_logit)
        
        return D_prob, D_logit
    
    def generator(z):
        G_h1 = tf.nn.relu(tf.matmul(z, G_W1) + G_b1)
        G_logit = tf.matmul(G_h1, G_W2) + G_b2
        G_prob = tf.sigmoid(G_logit)
        
        return G_prob
    
    def sample_z(m, n):
        return np.random.uniform(-1.0, 1.0, size=[m, n])
    
    G_sample = generator(Z)
    D_real, D_logit_real = discriminator(X)
    D_fake, D_logit_fake = discriminator(G_sample)
    
    D_loss = -tf.reduce_mean(tf.log(D_real) + tf.log(1.0 - D_fake))
    G_loss = -tf.reduce_mean(tf.log(D_fake))
    
    D_optimizer = tf.train.AdamOptimizer(learning_rate).minimize(D_loss, var_list=D_theta)
    G_optimizer = tf.train.AdamOptimizer(learning_rate).minimize(G_loss, var_list=G_theta)
    
    
    num_iters = 10000
    minibatch_size = 128
    
    with tf.Session(graph=graph) as session:
        tf.initialize_all_variables().run()
        print("Initialized")
        
        for iter in range(num_iters):
            X_batch, _ = mnist.train.next_batch(minibatch_size)
            Z_sample = sample_z(minibatch_size, 100)
            _, D_loss_curr = session.run([D_optimizer, D_loss], feed_dict={X: X_batch, Z: Z_sample})
            _, G_loss_curr = session.run([G_optimizer, G_loss], feed_dict={Z: Z_sample})
            
            if (iter%200) == 0:
                print("Minibatch D loss at step %d: %f" % (iter, D_loss_curr))
                print("Minibatch G loss at step %d: %f" % (iter, G_loss_curr))
                
            if (iter%1000) == 0:
                n = 3
                canvas = np.empty((28 * n, 28 * n))
                for i in range(n):
                    Z_test_sample = sample_z(n, 100)
                    G_test_sample = session.run(G_sample, feed_dict={Z: Z_test_sample})

                    G_test_sample = np.multiply((G_test_sample - 1.0), 1.0)
                    for j in range(n):
                        canvas[i*image_side_dimension:(i+1)*image_side_dimension, j*image_side_dimension:(j+1)*image_side_dimension] = G_test_sample[j].reshape([image_side_dimension, image_side_dimension])
                plt.figure(figsize=(n, n))
                plt.imshow(canvas, origin="upper", cmap="gray")
                plt.show()
# Out:
# WARNING:tensorflow:From <ipython-input-25-872e3dbfea76>:63 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Minibatch D loss at step 0: 1.180836
# Minibatch G loss at step 0: 3.507616
# Minibatch D loss at step 200: 0.025860
# Minibatch G loss at step 200: 5.644128
# Minibatch D loss at step 400: 0.004120
# Minibatch G loss at step 400: 6.961850
# Minibatch D loss at step 600: 0.002853
# Minibatch G loss at step 600: 9.188828
# Minibatch D loss at step 800: 0.008170
# Minibatch G loss at step 800: 11.990151
# Minibatch D loss at step 1000: 0.004211
# Minibatch G loss at step 1000: 7.479177
# Minibatch D loss at step 1200: 0.002672
# Minibatch G loss at step 1200: 8.960028
# Minibatch D loss at step 1400: 0.001735
# Minibatch G loss at step 1400: 9.605633
# Minibatch D loss at step 1600: 0.012984
# Minibatch G loss at step 1600: 9.262953
# Minibatch D loss at step 1800: 0.003768
# Minibatch G loss at step 1800: 10.517252
# Minibatch D loss at step 2000: 0.002360
# Minibatch G loss at step 2000: 8.787768
# Minibatch D loss at step 2200: 0.004586
# Minibatch G loss at step 2200: 7.362288
# Minibatch D loss at step 2400: 0.008011
# Minibatch G loss at step 2400: 7.420112
# Minibatch D loss at step 2600: 0.013028
# Minibatch G loss at step 2600: 8.081905
# Minibatch D loss at step 2800: 0.011508
# Minibatch G loss at step 2800: 9.077372
# Minibatch D loss at step 3000: 0.021545
# Minibatch G loss at step 3000: 8.505133
# Minibatch D loss at step 3200: 0.003648
# Minibatch G loss at step 3200: 11.488329
# Minibatch D loss at step 3400: 0.020872
# Minibatch G loss at step 3400: 9.706860
# Minibatch D loss at step 3600: 0.012164
# Minibatch G loss at step 3600: 8.430189
# Minibatch D loss at step 3800: 0.016728
# Minibatch G loss at step 3800: 8.087368
# Minibatch D loss at step 4000: 0.037934
# Minibatch G loss at step 4000: 7.512370
# Minibatch D loss at step 4200: 0.024396
# Minibatch G loss at step 4200: 9.314227
# Minibatch D loss at step 4400: 0.028488
# Minibatch G loss at step 4400: 9.567322
# Minibatch D loss at step 4600: 0.026085
# Minibatch G loss at step 4600: 8.715520
# Minibatch D loss at step 4800: 0.020517
# Minibatch G loss at step 4800: 8.093314
# Minibatch D loss at step 5000: 0.083333
# Minibatch G loss at step 5000: 6.323565
# Minibatch D loss at step 5200: 0.067217
# Minibatch G loss at step 5200: 7.970793
# Minibatch D loss at step 5400: 0.085593
# Minibatch G loss at step 5400: 7.049510
# Minibatch D loss at step 5600: 0.052588
# Minibatch G loss at step 5600: 6.026621
# Minibatch D loss at step 5800: 0.088047
# Minibatch G loss at step 5800: 5.386589
# Minibatch D loss at step 6000: 0.109423
# Minibatch G loss at step 6000: 6.201219
# Minibatch D loss at step 6200: 0.147291
# Minibatch G loss at step 6200: 5.229203
# Minibatch D loss at step 6400: 0.224618
# Minibatch G loss at step 6400: 4.857072
# Minibatch D loss at step 6600: 0.292497
# Minibatch G loss at step 6600: 4.477761
# Minibatch D loss at step 6800: 0.153430
# Minibatch G loss at step 6800: 4.503256
# Minibatch D loss at step 7000: 0.218041
# Minibatch G loss at step 7000: 4.056421
# Minibatch D loss at step 7200: 0.225397
# Minibatch G loss at step 7200: 4.212574
# Minibatch D loss at step 7400: 0.233987
# Minibatch G loss at step 7400: 3.623582
# Minibatch D loss at step 7600: 0.250599
# Minibatch G loss at step 7600: 3.795626
# Minibatch D loss at step 7800: 0.239406
# Minibatch G loss at step 7800: 3.407235
# Minibatch D loss at step 8000: 0.235289
# Minibatch G loss at step 8000: 4.074797
# Minibatch D loss at step 8200: 0.301067
# Minibatch G loss at step 8200: 4.297809
# Minibatch D loss at step 8400: 0.358308
# Minibatch G loss at step 8400: 3.588663
# Minibatch D loss at step 8600: 0.344105
# Minibatch G loss at step 8600: 3.638166
# Minibatch D loss at step 8800: 0.281599
# Minibatch G loss at step 8800: 3.314276
# Minibatch D loss at step 9000: 0.363164
# Minibatch G loss at step 9000: 3.781095
# Minibatch D loss at step 9200: 0.298031
# Minibatch G loss at step 9200: 3.730084
# Minibatch D loss at step 9400: 0.449592
# Minibatch G loss at step 9400: 3.205694
# Minibatch D loss at step 9600: 0.330677
# Minibatch G loss at step 9600: 3.840043
# Minibatch D loss at step 9800: 0.240773
# Minibatch G loss at step 9800: 3.855461
